# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import Axes3D 
# %matplotlib notebook

# %%
X = np.linspace(-5.12, 5.12, 100)     
Y = np.linspace(-5.12, 5.12, 100)     
X, Y = np.meshgrid(X, Y)

# %%
Z = (X**2 - 10 * np.cos(2 * np.pi * X)) + (Y**2 - 10 * np.cos(2 * np.pi * Y)) + 20

# %%
fig = plt.figure(figsize = (10,8)) 
ax = fig.gca(projection = '3d')
ax.plot_surface(X, Y, Z, rstride = 1, cstride = 1, cmap = cm.gist_yarg, linewidth = 1, antialiased = True)
ax.tick_params(labelsize = 16)
# Rotate the axes and update
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="998.6178503539132">

# %%
plt.savefig('rastrigin.eps', bbox_inches = 'tight')
