# %%
# pip install numpy
import numpy as np
# pip install tqdm
from tqdm import tqdm
# pip install pandas
import pandas as pd
# pip install seaborn
import seaborn as sns
# pip install matplotlib
import matplotlib.pyplot as plt

# %%
D = 10
cf_num = 10
n_exec = 31
n_configs = 8
max_eval = 100000
search_range = [-100, 100]

# %% [markdown]
# # Objective functions

# %%
shift_data = np.loadtxt(fname = 'shift_data.txt')
M_D10 = np.loadtxt(fname = 'M_D10.txt').reshape((cf_num, D, D))
M1 = M_D10[0].reshape((-1))
o = shift_data.reshape((-1))[:cf_num*D]

# %%
# Shift Function
def shift(x, o):
    
    xshift = x - o[:x.shape[0]]
        
    return xshift

# %%
# Rotate Function
def rotate(x, M1):
    
    xrot = np.zeros((x.shape[0]))
    
    for i in range(x.shape[0]):
        for j in range(x.shape[0]):
            xrot[i] = xrot[i] + x[j] * M1[i*D+j]
    
    return xrot

# %%
# Unimodal Function
def sphere(x, o, bias = -1400):
    
    """ Sphere function (CEC2013). """
       
    # Shift
    xshift = shift(x, o)
    
    # Sphere
    f = sum(xshift**2) + bias
    
    return f

# %%
# Minimum global
sphere(x = o[:D], o = o[:D])
# Out:
# -1400.0

# %%
# Basic Multimodal Function
def rosenbrock(x, o, M1, a = 1, b = 100, bias = -900):
    
    """ Rotated Rosenbrock's function (CEC2013)."""
    
    # Shift
    xshift = shift(x, o)
    # Shrink to the orginal search range
    xshift = 2.048/100*xshift
    # Rotate
    xrot = rotate(xshift, M1)
    # Shift to origin
    xrot = xrot + 1
    
    # Rosenbrock
    f = sum(b*(xrot[1:]-xrot[:-1]**2.0)**2.0 + (a-xrot[:-1])**2.0) + bias
    
    return f

# %%
# Minimum global
rosenbrock(x = o[:D], o = o[:D], M1 = M1)
# Out:
# -900.0

# %% [markdown]
# # Particle Swarm Optimization (PSO)

# %%
class ParticleSwarmOptimization():
    
    """ Global/Local Best Particle Swarm Optimization. """
    
    def __init__(self, n, m, fobj, max_eval, search_range, c1, c2, inertia, constriction, delta, neighborhood):
        
        """
            n: Number of dimensions
            m: Number of particles
            fobj: Unimodal ('sphere') or Multimodal ('rosenbrock')
            max_eval: Maximum number of function evaluations
            search_range: Search space range
            c1: Cognitive factor
            c2: Social factor
            inertia: Inertia weight
            constriction: Constriction coefficient
            delta: Factor for maximum velocity clamping
            neighborhood: Type of neighborhood for exploring solutions (global or local)
        """

        self.n = n
        self.m = m
        self.fobj = fobj
        self.n_eval = 0
        self.max_eval = max_eval
        self.search_range = search_range
        self.c1 = c1
        self.c2 = c2
        self.inertia = inertia
        self.constriction = constriction
        self.delta = delta
        self.neighborhood = neighborhood
        
        # Personal best: best position the particle has visited since the first time step 
        self.pbest = np.zeros((self.m, self.n))
        
        if self.neighborhood == 'global':
            # Global best position
            self.gbest = np.zeros((self.n,))
        else:
            # Best position found in the neighborhood of each particle
            self.gbest = np.zeros((self.m, self.n))
            
        # Minimization problem
        self.best_fitness = float('Inf')
        
    def objective_function(self, x, o = o, M1 = None):
        
        if self.fobj == 'sphere':
            f = sphere(x = x, o = o)
        else:
            f = rosenbrock(x = x, o = o, M1 = M1)
        
        return f
        
    def random_initialization(self, o = o, M1 = None):

        """ Random initialization method. """

        swarm = np.zeros((self.m, self.n))
        velocities = np.zeros((self.m, self.n))
        fitness = np.zeros((self.m,))

        for i in range(self.m):
            
            swarm[i] = np.random.uniform(low = self.search_range[0], high = self.search_range[1], size = self.n)
            # The personal best position of each particle is equal to its initial position
            self.pbest[i] = swarm[i].copy()
            # Evaluating particles
            fitness[i] = self.objective_function(x = swarm[i], o = o, M1 = M1)
            
        return swarm, fitness, velocities
    
    def solve(self, o, M1 = None):
    
        """ Minimizes optimization function. """
        
        # Initializes population with random candidate solutions
        swarm, fitness, velocities = self.random_initialization(o = o, M1 = M1)
        pbest_fitness = fitness.copy()
        
        # Maximum velocity
        v_max = self.delta * (search_range[1] - search_range[0])
        
        # Progress bar
        # pbar = tqdm(total = self.max_eval, desc = 'Function evaluations')
        
        # Minimum global
        if self.fobj == 'sphere':
            f_star = -1400
        else:
            f_star = -900

        # Until the maximum number of function evaluations is reached
        while self.n_eval < self.max_eval or self.best_fitness < f_star:
        
            # Set the personal best position
            for i in range(self.m):                
                if fitness[i] < pbest_fitness[i]:
                    self.pbest[i] = swarm[i].copy()
                    pbest_fitness[i] = fitness[i]
            
            # Set the global best position (global best)
            if self.neighborhood == 'global':                
                self.gbest = self.pbest[np.argmin(pbest_fitness)]
                
            # Set the global best position (local best)
            else:                
                for i in range(self.m):                    
                    # Ring neighborhood structure
                    neighbors = [((i-1)%self.m), i, ((i+1)%self.m)]
                    neighbor_fitness = pbest_fitness[neighbors]
                    self.gbest[i] = self.pbest[neighbors[np.argmin(neighbor_fitness)]]
                    
            for i in range(self.m):
                
                r1 = np.random.uniform(low = 0, high = 1, size = self.n)
                r2 = np.random.uniform(low = 0, high = 1, size = self.n)
                
                # Update velocities
                if self.neighborhood == 'global':
                    velocities[i] = self.constriction*(self.inertia*velocities[i] + (self.c1*r1) * (self.pbest[i] - swarm[i]) + (self.c2*r2) * (self.gbest - swarm[i]))
                else:
                    velocities[i] = self.constriction*(self.inertia*velocities[i] + (self.c1*r1) * (self.pbest[i] - swarm[i]) + (self.c2*r2) * (self.gbest[i] - swarm[i]))
                
                # Update positions
                swarm[i] = swarm[i] + velocities[i]
                
                # Update fitness
                fitness[i] = self.objective_function(x = swarm[i], o = o, M1 = M1)
                
                # Update best solution
                if fitness[i] < self.best_fitness:
                    self.best_fitness = fitness[i]
            
            # Limits for the positions and velocities of a particle
            velocities[velocities > v_max] = v_max
            swarm[swarm < self.search_range[0]] = self.search_range[0]
            swarm[swarm > self.search_range[1]] = self.search_range[1]
                
            # Increases number of function evaluations
            self.n_eval = self.n_eval + self.m
            # pbar.update(self.m)

# %% [markdown]
# # Experiments
# ### This may take a few minutes ...

# %%
results = list()

fobjs = ['sphere', 'rosenbrock']
neighborhoods = ['global', 'local']
hyperparams = [(1.0, 1.0), (1.0, 0.5), (0.5, 1.0), (0.5, 0.5)]

for i in range(len(neighborhoods)):
    
    for j in range(len(hyperparams)):
        
        for k in range(len(fobjs)):
            
            print('Neighborhood:', neighborhoods[i])
            print('Hyperparameters:', hyperparams[j]) 
            print('Objective Function:', fobjs[k])
    
            for l in range(n_exec):

                PSO = ParticleSwarmOptimization(n = D, 
                                    m = 100, 
                                    fobj = fobjs[k], 
                                    max_eval = max_eval, 
                                    search_range = search_range,
                                    c1 = 2.05,
                                    c2 = 2.05,
                                    inertia = hyperparams[j][1],
                                    constriction = hyperparams[j][0],
                                    delta = 0.8,
                                    neighborhood = neighborhoods[i])

                PSO.solve(o = o, M1 = M1)
                results.append(PSO.best_fitness)
                del PSO
        
            print('\n')
        
results = np.resize(np.asarray(results), (2*n_configs, n_exec))
print(results.shape)
# Out:
# Neighborhood: global
# Hyperparameters: (1.0, 1.0)
# Objective Function: sphere
#
#
# Neighborhood: global
# Hyperparameters: (1.0, 1.0)
# Objective Function: rosenbrock
#
#
# Neighborhood: global
# Hyperparameters: (1.0, 0.5)
# Objective Function: sphere
#
#
# Neighborhood: global
# Hyperparameters: (1.0, 0.5)
# Objective Function: rosenbrock
#
#
# Neighborhood: global
# Hyperparameters: (0.5, 1.0)
# Objective Function: sphere
#
#
# Neighborhood: global
# Hyperparameters: (0.5, 1.0)
# Objective Function: rosenbrock
#
#
# Neighborhood: global
# Hyperparameters: (0.5, 0.5)
# Objective Function: sphere
#
#
# Neighborhood: global
# Hyperparameters: (0.5, 0.5)
# Objective Function: rosenbrock
#
#
# Neighborhood: local
# Hyperparameters: (1.0, 1.0)
# Objective Function: sphere
#
#
# Neighborhood: local
# Hyperparameters: (1.0, 1.0)
# Objective Function: rosenbrock
#
#
# Neighborhood: local
# Hyperparameters: (1.0, 0.5)
# Objective Function: sphere
#
#
# Neighborhood: local
# Hyperparameters: (1.0, 0.5)
# Objective Function: rosenbrock
#
#
# Neighborhood: local
# Hyperparameters: (0.5, 1.0)
# Objective Function: sphere
#
#
# Neighborhood: local
# Hyperparameters: (0.5, 1.0)
# Objective Function: rosenbrock
#
#
# Neighborhood: local
# Hyperparameters: (0.5, 0.5)
# Objective Function: sphere
#
#
# Neighborhood: local
# Hyperparameters: (0.5, 0.5)
# Objective Function: rosenbrock
#
#
# (16, 31)

# %%
with open('results.npy', 'wb') as f:
    np.save(f, results)

# %%
results = pd.DataFrame(results)
results = results.T
results.head()
# Out:
#             0           1       2           3       4           5   \
# 0  1095.139020 -781.811496 -1400.0 -889.863975 -1400.0 -818.547625
# 1  1680.862653 -804.789578 -1400.0 -890.221465 -1400.0 -899.464116
# 2  1081.662845 -775.764448 -1400.0 -853.154952 -1400.0 -815.177148
# 3  2040.245886 -838.527329 -1400.0 -889.863975 -1400.0 -898.902117
# 4   672.123724 -791.669339 -1400.0 -889.975593 -1400.0 -826.564654
#
#             6           7            8           9       10          11  \
# 0 -1390.660294 -757.740945  1100.356240 -766.464297 -1400.0 -890.503949
# 1 -1398.848385 -864.143343   500.040700 -802.613656 -1400.0 -899.857635
# 2 -1129.744618 -843.963279  1311.109603 -836.980234 -1400.0 -898.337376
# 3 -1102.131715 -860.591533  1825.363632 -809.730917 -1400.0 -891.796693
# 4 -1216.874840 -822.733256  1340.332786 -801.592389 -1400.0 -898.252344
#
#        12          13           14          15
# 0 -1400.0 -891.581821 -1399.994517 -889.551036
# 1 -1400.0 -899.841106 -1399.999682 -865.854567
# 2 -1400.0 -899.932681 -1399.999495 -887.858890
# 3 -1400.0 -899.991211 -1399.987382 -890.180523
# 4 -1400.0 -899.993941 -1399.997325 -899.978951

# %%
# Global Best PSO and Sphere Function
gfun1 = results.get([0, 2, 4, 6])
# Global Best PSO and Rosenbrock Function
gfun2 = results.get([1, 3, 5, 7])
# Local Best PSO and Sphere Function
lfun1 = results.get([8, 10, 12, 14])
# Local Best PSO and Rosenbrock Function
lfun2 = results.get([9, 11, 13, 15])

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (7, 6))
sns.boxplot(data = gfun1, palette = 'Greys_r', width = 0.5)
sns.lineplot(data = gfun1.mean().values, lw = 2, color = 'black')
sns.scatterplot(data = gfun1.mean().values, color = 'black', s = 50, linewidth = 0)
plt.xticks(labels = [1, 2, 3, 4], ticks = [0, 1, 2, 3], fontsize = 16)
plt.yticks(fontsize = 16)
plt.ylabel('$f(\mathbf{x^{*}}$)', fontsize = 16)
plt.xlabel('cfg', fontsize = 16)
plt.savefig('global_sphere.eps', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (7, 6))
sns.boxplot(data = gfun2, palette = 'Greys_r', width = 0.5)
sns.lineplot(data = gfun2.mean().values, lw = 2, color = 'black')
sns.scatterplot(data = gfun2.mean().values, color = 'black', s = 50, linewidth = 0)
plt.xticks(labels = [1, 2, 3, 4], ticks = [0, 1, 2, 3], fontsize = 16)
plt.yticks(fontsize = 16)
plt.ylabel('$f(\mathbf{x^{*}}$)', fontsize = 16)
plt.xlabel('cfg', fontsize = 16)
plt.savefig('global_rosenbrock.eps', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (7, 6))
sns.boxplot(data = lfun1, palette = 'Greys_r', width = 0.5)
sns.lineplot(data = lfun1.mean().values, lw = 2, color = 'black')
sns.scatterplot(data = lfun1.mean().values, color = 'black', s = 50, linewidth = 0)
plt.xticks(labels = [1, 2, 3, 4], ticks = [0, 1, 2, 3], fontsize = 16)
plt.yticks(fontsize = 16)
plt.ylabel('$f(\mathbf{x^{*}}$)', fontsize = 16)
plt.xlabel('cfg', fontsize = 16)
plt.savefig('local_sphere.eps', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (7, 6))
sns.boxplot(data = lfun2, palette = 'Greys_r', width = 0.5)
sns.lineplot(data = lfun2.mean().values, lw = 2, color = 'black')
sns.scatterplot(data = lfun2.mean().values, color = 'black', s = 50, linewidth = 0)
plt.xticks(labels = [1, 2, 3, 4], ticks = [0, 1, 2, 3], fontsize = 16)
plt.yticks(fontsize = 16)
plt.ylabel('$f(\mathbf{x^{*}}$)', fontsize = 16)
plt.xlabel('cfg', fontsize = 16)
plt.savefig('local_rosenbrock.eps', dpi = 300, bbox_inches = 'tight')
plt.show()
